# %%
import requests
import json
import pandas as pd
from pprint import pprint

# %%
hub="ATL"
prices_url=f"http://api.travelpayouts.com/v2/prices/latest?currency=usd&limit=500&origin={hub}"
headers = {"X-Access-Token": "f2b1a8fac25474496ea091529cddd0ec",
         }
prices_data = requests.get(prices_url, headers=headers).json()
pprint(prices_data)
# Out:
# {'data': [{'actual': True,
#            'depart_date': '2018-11-03',
#            'destination': 'ORL',
#            'distance': 647,
#            'duration': 105,
#            'found_at': '2018-09-29T20:52:25',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-11-09',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 46.5},
#           {'actual': True,
#            'depart_date': '2018-11-10',
#            'destination': 'DTT',
#            'distance': 963,
#            'duration': 124,
#            'found_at': '2018-09-30T13:46:06',
#            'gate': 'JustFly',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-11-13',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 82.37},
#           {'actual': True,
#            'depart_date': '2019-01-31',
#            'destination': 'MIA',
#            'distance': 973,
#            'duration': 121,
#            'found_at': '2018-09-30T15:43:34',
#            'gate': 'OneTravel',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2019-02-12',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 93.37},
#           {'actual': True,
#            'depart_date': '2018-12-01',
#            'destination': 'CHI',
#            'distance': 949,
#            'duration': 115,
#            'found_at': '2018-09-30T17:45:58',
#            'gate': 'MyHolidays',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-12-08',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 96.81},
#           {'actual': True,
#            'depart_date': '2018-10-31',
#            'destination': 'DFW',
#            'distance': 1156,
#            'duration': 145,
#            'found_at': '2018-09-30T15:38:58',
#            'gate': 'CompassFlights',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-11-03',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 96.95},
#           {'actual': True,
#            'depart_date': '2018-10-24',
#            'destination': 'FLL',
#            'distance': 942,
#            'duration': 113,
#            'found_at': '2018-09-30T14:54:44',
#            'gate': 'JustFly',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-10-29',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 102.39},
#           {'actual': True,
#            'depart_date': '2018-10-18',
#            'destination': 'MSP',
#            'distance': 1463,
#            'duration': 161,
#            'found_at': '2018-09-30T15:41:09',
#            'gate': 'JustFly',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-10-22',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 102.39},
#           {'actual': True,
#            'depart_date': '2018-12-12',
#            'destination': 'BWI',
#            'distance': 929,
#            'duration': 126,
#            'found_at': '2018-09-30T14:31:14',
#            'gate': 'JustFly',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-12-14',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 106.39},
#           {'actual': True,
#            'depart_date': '2018-10-26',
#            'destination': 'HOU',
#            'distance': 1131,
#            'duration': 131,
#            'found_at': '2018-09-29T21:50:00',
#            'gate': 'JustFly',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-10-29',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 108.37},
#           {'actual': True,
#            'depart_date': '2018-11-09',
#            'destination': 'BOS',
#            'distance': 1508,
#            'duration': 172,
#            'found_at': '2018-09-30T23:08:13',
#            'gate': 'CompassFlights',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-11-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 111.53},
#           {'actual': True,
#            'depart_date': '2018-10-26',
#            'destination': 'PHL',
#            'distance': 1072,
#            'duration': 136,
#            'found_at': '2018-10-01T17:54:26',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-10-29',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 117.78},
#           {'actual': True,
#            'depart_date': '2018-10-14',
#            'destination': 'TPA',
#            'distance': 671,
#            'duration': 94,
#            'found_at': '2018-09-30T22:09:53',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-10-16',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 118.78},
#           {'actual': True,
#            'depart_date': '2018-10-18',
#            'destination': 'MSY',
#            'distance': 683,
#            'duration': 604,
#            'found_at': '2018-10-01T00:24:51',
#            'gate': 'JustFly',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-20',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 125.6},
#           {'actual': True,
#            'depart_date': '2018-10-31',
#            'destination': 'NYC',
#            'distance': 1202,
#            'duration': 147,
#            'found_at': '2018-10-01T07:41:08',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-11-03',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 127.91},
#           {'actual': True,
#            'depart_date': '2018-12-08',
#            'destination': 'LAS',
#            'distance': 2810,
#            'duration': 282,
#            'found_at': '2018-10-01T12:06:53',
#            'gate': 'OneTravel',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-12-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 146.39},
#           {'actual': True,
#            'depart_date': '2018-10-12',
#            'destination': 'DEN',
#            'distance': 1949,
#            'duration': 201,
#            'found_at': '2018-09-30T23:46:34',
#            'gate': 'SmartFares',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-10-15',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 152.95},
#           {'actual': True,
#            'depart_date': '2019-02-01',
#            'destination': 'DAB',
#            'distance': 598,
#            'duration': 92,
#            'found_at': '2018-09-30T21:25:24',
#            'gate': 'Justairticket',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2019-02-04',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 152.99},
#           {'actual': True,
#            'depart_date': '2018-11-03',
#            'destination': 'CHO',
#            'distance': 724,
#            'duration': 245,
#            'found_at': '2018-09-30T01:18:11',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-07',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 168.67},
#           {'actual': True,
#            'depart_date': '2018-12-20',
#            'destination': 'CLE',
#            'distance': 895,
#            'duration': 119,
#            'found_at': '2018-10-01T11:27:08',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-12-27',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 169.92},
#           {'actual': True,
#            'depart_date': '2018-10-20',
#            'destination': 'RIC',
#            'distance': 755,
#            'duration': 1163,
#            'found_at': '2018-10-01T07:45:55',
#            'gate': 'OneTravel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-24',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 171.52},
#           {'actual': True,
#            'depart_date': '2018-10-27',
#            'destination': 'SAT',
#            'distance': 1420,
#            'duration': 328,
#            'found_at': '2018-09-30T01:59:31',
#            'gate': 'Vayama',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-29',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 181.31},
#           {'actual': True,
#            'depart_date': '2018-11-09',
#            'destination': 'WAS',
#            'distance': 873,
#            'duration': 105,
#            'found_at': '2018-09-30T18:32:54',
#            'gate': 'CompassFlights',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-11-12',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 186.83},
#           {'actual': True,
#            'depart_date': '2018-11-10',
#            'destination': 'PBI',
#            'distance': 887,
#            'duration': 110,
#            'found_at': '2018-09-29T20:10:18',
#            'gate': 'MyHolidays',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-11-12',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 188.81},
#           {'actual': True,
#            'depart_date': '2018-11-02',
#            'destination': 'BNA',
#            'distance': 337,
#            'duration': 70,
#            'found_at': '2018-09-30T20:45:23',
#            'gate': 'MyHolidays',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-11-04',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 188.81},
#           {'actual': True,
#            'depart_date': '2018-11-28',
#            'destination': 'MKC',
#            'distance': 1086,
#            'duration': 440,
#            'found_at': '2018-09-30T23:44:25',
#            'gate': 'Vayama',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-01-03',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 189.01},
#           {'actual': True,
#            'depart_date': '2018-12-18',
#            'destination': 'IND',
#            'distance': 686,
#            'duration': 100,
#            'found_at': '2018-09-30T20:56:29',
#            'gate': 'MyHolidays',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-12-21',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 190.8},
#           {'actual': True,
#            'depart_date': '2018-12-08',
#            'destination': 'BDL',
#            'distance': 1372,
#            'duration': 1601,
#            'found_at': '2018-10-01T10:04:44',
#            'gate': 'SmartFares',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-12-15',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 197.1},
#           {'actual': True,
#            'depart_date': '2018-11-12',
#            'destination': 'LAX',
#            'distance': 3114,
#            'duration': 304,
#            'found_at': '2018-09-29T23:06:16',
#            'gate': 'MyHolidays',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-12-10',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 199.02},
#           {'actual': True,
#            'depart_date': '2018-10-29',
#            'destination': 'SLC',
#            'distance': 2554,
#            'duration': 1108,
#            'found_at': '2018-09-30T00:13:28',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-01',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 202.0},
#           {'actual': True,
#            'depart_date': '2018-10-31',
#            'destination': 'PHX',
#            'distance': 2560,
#            'duration': 583,
#            'found_at': '2018-09-30T16:04:35',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-03',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 202.88},
#           {'actual': True,
#            'depart_date': '2018-11-18',
#            'destination': 'RDU',
#            'distance': 563,
#            'duration': 85,
#            'found_at': '2018-10-01T06:33:20',
#            'gate': 'MyHolidays',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-11-20',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 209.82},
#           {'actual': True,
#            'depart_date': '2018-10-23',
#            'destination': 'ISP',
#            'distance': 1269,
#            'duration': 360,
#            'found_at': '2018-09-30T02:06:13',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-30',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 212.77},
#           {'actual': True,
#            'depart_date': '2018-12-14',
#            'destination': 'SYR',
#            'distance': 1259,
#            'duration': 148,
#            'found_at': '2018-10-01T03:05:41',
#            'gate': 'Justairticket',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2019-01-12',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 219.99},
#           {'actual': True,
#            'depart_date': '2018-10-19',
#            'destination': 'CVG',
#            'distance': 594,
#            'duration': 91,
#            'found_at': '2018-10-01T17:45:46',
#            'gate': 'Justairticket',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-10-21',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 219.99},
#           {'actual': True,
#            'depart_date': '2019-01-25',
#            'destination': 'SJU',
#            'distance': 2489,
#            'duration': 656,
#            'found_at': '2018-09-30T01:40:51',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-01-28',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 220.41},
#           {'actual': True,
#            'depart_date': '2018-12-20',
#            'destination': 'PIT',
#            'distance': 841,
#            'duration': 110,
#            'found_at': '2018-10-01T03:09:37',
#            'gate': 'MyHolidays',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-12-29',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 225.81},
#           {'actual': True,
#            'depart_date': '2018-10-17',
#            'destination': 'CLT',
#            'distance': 364,
#            'duration': 762,
#            'found_at': '2018-09-30T04:55:19',
#            'gate': 'City.Travel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-17',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 235.29},
#           {'actual': True,
#            'depart_date': '2018-12-30',
#            'destination': 'VPS',
#            'distance': 415,
#            'duration': 258,
#            'found_at': '2018-10-01T04:52:09',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-01-03',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 237.93},
#           {'actual': True,
#            'depart_date': '2018-12-07',
#            'destination': 'STT',
#            'distance': 2585,
#            'duration': 1480,
#            'found_at': '2018-09-29T21:34:21',
#            'gate': 'SmartFares',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-12-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 240.89},
#           {'actual': True,
#            'depart_date': '2018-10-13',
#            'destination': 'SAC',
#            'distance': 3354,
#            'duration': 507,
#            'found_at': '2018-10-01T16:54:53',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-16',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 240.9},
#           {'actual': True,
#            'depart_date': '2018-11-08',
#            'destination': 'COS',
#            'distance': 1914,
#            'duration': 360,
#            'found_at': '2018-09-29T20:44:56',
#            'gate': 'Vayama',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-13',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 242.99},
#           {'actual': True,
#            'depart_date': '2018-10-25',
#            'destination': 'FSD',
#            'distance': 1529,
#            'duration': 556,
#            'found_at': '2018-09-30T14:47:15',
#            'gate': 'MyHolidays',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-10-30',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 248.02},
#           {'actual': True,
#            'depart_date': '2018-10-31',
#            'destination': 'BIS',
#            'distance': 2001,
#            'duration': 1329,
#            'found_at': '2018-09-30T11:50:45',
#            'gate': 'Vayama',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-05',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 253.59},
#           {'actual': True,
#            'depart_date': '2018-12-19',
#            'destination': 'MKE',
#            'distance': 1078,
#            'duration': 132,
#            'found_at': '2018-09-30T14:51:40',
#            'gate': 'Justairticket',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-12-27',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 261.0},
#           {'actual': True,
#            'depart_date': '2019-04-01',
#            'destination': 'OKC',
#            'distance': 1217,
#            'duration': 385,
#            'found_at': '2018-10-01T12:41:14',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-04-03',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 261.29},
#           {'actual': True,
#            'depart_date': '2018-11-30',
#            'destination': 'SEA',
#            'distance': 3510,
#            'duration': 629,
#            'found_at': '2018-10-01T06:48:20',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-12-04',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 264.2},
#           {'actual': True,
#            'depart_date': '2018-11-01',
#            'destination': 'SAN',
#            'distance': 3041,
#            'duration': 891,
#            'found_at': '2018-09-30T16:26:08',
#            'gate': 'JustFly',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-05',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 264.6},
#           {'actual': True,
#            'depart_date': '2018-10-14',
#            'destination': 'STL',
#            'distance': 753,
#            'duration': 1846,
#            'found_at': '2018-10-01T12:08:46',
#            'gate': 'OneTravel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-16',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 266.78},
#           {'actual': True,
#            'depart_date': '2018-10-25',
#            'destination': 'YVR',
#            'distance': 3607,
#            'duration': 1082,
#            'found_at': '2018-10-01T18:15:51',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-29',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 267.61},
#           {'actual': True,
#            'depart_date': '2018-10-27',
#            'destination': 'HPN',
#            'distance': 1246,
#            'duration': 309,
#            'found_at': '2018-09-29T21:29:54',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-01',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 268.3},
#           {'actual': True,
#            'depart_date': '2019-03-16',
#            'destination': 'FWA',
#            'distance': 819,
#            'duration': 117,
#            'found_at': '2018-09-29T23:38:57',
#            'gate': 'Justairticket',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2019-03-21',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 271.0},
#           {'actual': True,
#            'depart_date': '2018-10-21',
#            'destination': 'YTO',
#            'distance': 1185,
#            'duration': 349,
#            'found_at': '2018-09-30T19:55:01',
#            'gate': 'Justairticket',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-26',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 280.99},
#           {'actual': True,
#            'depart_date': '2018-10-23',
#            'destination': 'ORF',
#            'distance': 813,
#            'duration': 417,
#            'found_at': '2018-10-01T01:31:00',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-23',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 287.1},
#           {'actual': True,
#            'depart_date': '2018-10-12',
#            'destination': 'PWM',
#            'distance': 1642,
#            'duration': 765,
#            'found_at': '2018-09-30T23:45:51',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-15',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 296.99},
#           {'actual': True,
#            'depart_date': '2018-11-08',
#            'destination': 'MEX',
#            'distance': 2162,
#            'duration': 425,
#            'found_at': '2018-10-01T17:03:27',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-14',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 304.57},
#           {'actual': True,
#            'depart_date': '2018-10-08',
#            'destination': 'OAK',
#            'distance': 3427,
#            'duration': 1391,
#            'found_at': '2018-09-30T19:28:20',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-10',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 312.0},
#           {'actual': True,
#            'depart_date': '2018-12-12',
#            'destination': 'ZSH',
#            'distance': 12441,
#            'duration': 368,
#            'found_at': '2018-10-01T14:48:10',
#            'gate': 'Justairticket',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-12-19',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 312.0},
#           {'actual': True,
#            'depart_date': '2018-10-03',
#            'destination': 'AIY',
#            'distance': 1085,
#            'duration': 347,
#            'found_at': '2018-10-01T11:54:06',
#            'gate': 'OneTravel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-06',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 317.96},
#           {'actual': True,
#            'depart_date': '2019-04-07',
#            'destination': 'EYW',
#            'distance': 1054,
#            'duration': 121,
#            'found_at': '2018-09-30T19:10:27',
#            'gate': 'Justairticket',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2019-04-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 321.01},
#           {'actual': True,
#            'depart_date': '2018-11-03',
#            'destination': 'SHD',
#            'distance': 717,
#            'duration': 236,
#            'found_at': '2018-09-30T01:19:13',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-07',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 321.65},
#           {'actual': True,
#            'depart_date': '2019-01-15',
#            'destination': 'PDX',
#            'distance': 3489,
#            'duration': 1938,
#            'found_at': '2018-10-01T05:57:36',
#            'gate': 'JustFly',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-18',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 322.73},
#           {'actual': True,
#            'depart_date': '2019-05-18',
#            'destination': 'HAV',
#            'distance': 1212,
#            'duration': 825,
#            'found_at': '2018-09-30T22:21:46',
#            'gate': 'City.Travel',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-05-23',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 327.76},
#           {'actual': True,
#            'depart_date': '2019-05-06',
#            'destination': 'SFO',
#            'distance': 3441,
#            'duration': 555,
#            'found_at': '2018-10-01T13:21:23',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-05-07',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 332.47},
#           {'actual': True,
#            'depart_date': '2019-01-24',
#            'destination': 'MBJ',
#            'distance': 1816,
#            'duration': 501,
#            'found_at': '2018-09-30T16:16:01',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-01-31',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 338.43},
#           {'actual': True,
#            'depart_date': '2019-05-02',
#            'destination': 'HRL',
#            'distance': 1528,
#            'duration': 420,
#            'found_at': '2018-09-29T23:07:03',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-05-06',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 343.28},
#           {'actual': True,
#            'depart_date': '2018-11-21',
#            'destination': 'CAK',
#            'distance': 839,
#            'duration': 1733,
#            'found_at': '2018-09-30T15:06:07',
#            'gate': 'OneTravel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-25',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 346.79},
#           {'actual': True,
#            'depart_date': '2018-12-14',
#            'destination': 'CUN',
#            'distance': 1436,
#            'duration': 456,
#            'found_at': '2018-09-30T16:20:29',
#            'gate': 'SmartFares',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-12-24',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 348.19},
#           {'actual': True,
#            'depart_date': '2019-01-24',
#            'destination': 'SJO',
#            'distance': 2644,
#            'duration': 1432,
#            'found_at': '2018-10-01T00:18:50',
#            'gate': 'SmartFares',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-01-28',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 353.48},
#           {'actual': True,
#            'depart_date': '2018-11-26',
#            'destination': 'MDE',
#            'distance': 3195,
#            'duration': 569,
#            'found_at': '2018-09-30T00:50:10',
#            'gate': 'SmartFares',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-12-06',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 357.6},
#           {'actual': True,
#            'depart_date': '2019-05-02',
#            'destination': 'CRP',
#            'distance': 1408,
#            'duration': 347,
#            'found_at': '2018-09-29T23:15:18',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-05-06',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 362.7},
#           {'actual': True,
#            'depart_date': '2018-10-19',
#            'destination': 'LNK',
#            'distance': 1348,
#            'duration': 147,
#            'found_at': '2018-09-30T18:03:26',
#            'gate': 'Justairticket',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-10-26',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 364.99},
#           {'actual': True,
#            'depart_date': '2018-12-07',
#            'destination': 'NAS',
#            'distance': 1183,
#            'duration': 946,
#            'found_at': '2018-09-29T21:16:51',
#            'gate': 'OneTravel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-12-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 367.99},
#           {'actual': True,
#            'depart_date': '2018-11-17',
#            'destination': 'FMY',
#            'distance': 827,
#            'duration': 110,
#            'found_at': '2018-10-01T16:55:09',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-11-24',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 370.63},
#           {'actual': True,
#            'depart_date': '2018-10-18',
#            'destination': 'BOG',
#            'distance': 3403,
#            'duration': 1329,
#            'found_at': '2018-10-01T11:54:55',
#            'gate': 'SmartFares',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-21',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 376.65},
#           {'actual': True,
#            'depart_date': '2018-10-29',
#            'destination': 'LIH',
#            'distance': 7340,
#            'duration': 828,
#            'found_at': '2018-10-01T17:00:31',
#            'gate': 'MyHolidays',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-11-07',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 379.35},
#           {'actual': True,
#            'depart_date': '2018-10-25',
#            'destination': 'HNL',
#            'distance': 7238,
#            'duration': 1182,
#            'found_at': '2018-10-01T17:13:41',
#            'gate': 'CompassFlights',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-11-05',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 383.53},
#           {'actual': True,
#            'depart_date': '2018-12-07',
#            'destination': 'AUA',
#            'distance': 2778,
#            'duration': 1616,
#            'found_at': '2018-09-29T21:31:44',
#            'gate': 'OneTravel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-12-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 394.68},
#           {'actual': True,
#            'depart_date': '2018-11-02',
#            'destination': 'SNA',
#            'distance': 3082,
#            'duration': 1414,
#            'found_at': '2018-09-29T21:40:57',
#            'gate': 'OneTravel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-04',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 395.79},
#           {'actual': True,
#            'depart_date': '2018-11-15',
#            'destination': 'REK',
#            'distance': 5358,
#            'duration': 787,
#            'found_at': '2018-09-30T06:51:17',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-29',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 399.1},
#           {'actual': True,
#            'depart_date': '2019-01-20',
#            'destination': 'KIN',
#            'distance': 1910,
#            'duration': 635,
#            'found_at': '2018-09-30T16:12:13',
#            'gate': 'FlyFar',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-01-27',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 401.02},
#           {'actual': True,
#            'depart_date': '2018-12-01',
#            'destination': 'SAP',
#            'distance': 2067,
#            'duration': 945,
#            'found_at': '2018-09-30T18:43:24',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-01-01',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 403.47},
#           {'actual': True,
#            'depart_date': '2018-10-31',
#            'destination': 'YUM',
#            'distance': 2808,
#            'duration': 628,
#            'found_at': '2018-09-30T16:03:37',
#            'gate': 'City.Travel',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-11-03',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 423.96},
#           {'actual': True,
#            'depart_date': '2018-11-17',
#            'destination': 'ONT',
#            'distance': 3059,
#            'duration': 1330,
#            'found_at': '2018-10-01T01:57:06',
#            'gate': 'City.Travel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-24',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 441.07},
#           {'actual': True,
#            'depart_date': '2018-11-20',
#            'destination': 'ELP',
#            'distance': 2077,
#            'duration': 423,
#            'found_at': '2018-09-30T05:30:26',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-25',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 468.15},
#           {'actual': True,
#            'depart_date': '2018-12-10',
#            'destination': 'PAR',
#            'distance': 7045,
#            'duration': 1645,
#            'found_at': '2018-09-29T23:49:18',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-01-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 471.49},
#           {'actual': True,
#            'depart_date': '2018-11-14',
#            'destination': 'MAD',
#            'distance': 6951,
#            'duration': 931,
#            'found_at': '2018-09-30T15:31:28',
#            'gate': 'CheapOair.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-27',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 473.8},
#           {'actual': True,
#            'depart_date': '2018-12-23',
#            'destination': 'SAL',
#            'distance': 2309,
#            'duration': 1712,
#            'found_at': '2018-09-30T00:41:11',
#            'gate': 'SmartFares',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-23',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 480.82},
#           {'actual': True,
#            'depart_date': '2018-10-08',
#            'destination': 'BUR',
#            'distance': 3121,
#            'duration': 1895,
#            'found_at': '2018-09-30T12:27:38',
#            'gate': 'OneTravel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 485.79},
#           {'actual': True,
#            'depart_date': '2018-12-01',
#            'destination': 'LON',
#            'distance': 6790,
#            'duration': 1365,
#            'found_at': '2018-10-01T17:08:03',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-12-09',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 491.52},
#           {'actual': True,
#            'depart_date': '2018-12-15',
#            'destination': 'GDL',
#            'distance': 2375,
#            'duration': 1511,
#            'found_at': '2018-09-30T23:04:27',
#            'gate': 'City.Travel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-12-23',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 494.22},
#           {'actual': True,
#            'depart_date': '2019-01-03',
#            'destination': 'PVR',
#            'distance': 2518,
#            'duration': 1044,
#            'found_at': '2018-09-30T17:35:42',
#            'gate': 'Cheaptickets.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-01-08',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 498.62},
#           {'actual': True,
#            'depart_date': '2019-01-18',
#            'destination': 'BJX',
#            'distance': 2202,
#            'duration': 220,
#            'found_at': '2018-10-01T16:30:16',
#            'gate': 'SmartFares',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2019-02-04',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 507.24},
#           {'actual': True,
#            'depart_date': '2018-11-14',
#            'destination': 'ALC',
#            'distance': 7297,
#            'duration': 1840,
#            'found_at': '2018-09-30T15:27:21',
#            'gate': 'Cheapfaremart',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-11-27',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 531.86},
#           {'actual': True,
#            'depart_date': '2018-10-13',
#            'destination': 'MLU',
#            'distance': 727,
#            'duration': 282,
#            'found_at': '2018-10-01T18:41:17',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-14',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 533.34},
#           {'actual': True,
#            'depart_date': '2018-10-06',
#            'destination': 'GNV',
#            'distance': 494,
#            'duration': 81,
#            'found_at': '2018-09-30T19:46:20',
#            'gate': 'Justairticket',
#            'number_of_changes': 0,
#            'origin': 'ATL',
#            'return_date': '2018-10-07',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 539.99},
#           {'actual': True,
#            'depart_date': '2018-11-20',
#            'destination': 'BCN',
#            'distance': 7361,
#            'duration': 1705,
#            'found_at': '2018-09-29T22:16:50',
#            'gate': 'Cheapfaremart',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-26',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 544.73},
#           {'actual': True,
#            'depart_date': '2019-03-12',
#            'destination': 'MLA',
#            'distance': 8596,
#            'duration': 2185,
#            'found_at': '2018-09-30T20:36:25',
#            'gate': 'Justairticket',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-03-25',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 549.0},
#           {'actual': True,
#            'depart_date': '2018-12-29',
#            'destination': 'ZRH',
#            'distance': 7534,
#            'duration': 933,
#            'found_at': '2018-10-01T12:17:36',
#            'gate': 'Justairticket',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-01-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 552.0},
#           {'actual': True,
#            'depart_date': '2018-11-15',
#            'destination': 'PUJ',
#            'distance': 2322,
#            'duration': 539,
#            'found_at': '2018-09-30T01:38:08',
#            'gate': 'Vayama',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-20',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 557.99},
#           {'actual': True,
#            'depart_date': '2018-10-04',
#            'destination': 'BUF',
#            'distance': 1125,
#            'duration': 288,
#            'found_at': '2018-10-01T13:36:44',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-07',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 559.04},
#           {'actual': True,
#            'depart_date': '2018-11-06',
#            'destination': 'BRU',
#            'distance': 7096,
#            'duration': 1937,
#            'found_at': '2018-10-01T01:07:34',
#            'gate': 'Vayama',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-11-20',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 562.7},
#           {'actual': True,
#            'depart_date': '2019-03-30',
#            'destination': 'SJD',
#            'distance': 2735,
#            'duration': 1130,
#            'found_at': '2018-09-29T22:14:41',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-04-06',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 564.47},
#           {'actual': True,
#            'depart_date': '2018-11-09',
#            'destination': 'MVY',
#            'distance': 1481,
#            'duration': 1533,
#            'found_at': '2018-09-30T23:08:22',
#            'gate': 'JustFly',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 571.19},
#           {'actual': True,
#            'depart_date': '2019-02-20',
#            'destination': 'OGG',
#            'distance': 7131,
#            'duration': 831,
#            'found_at': '2018-09-29T21:13:25',
#            'gate': 'Kiwi.com',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-02-26',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 571.99},
#           {'actual': True,
#            'depart_date': '2019-01-09',
#            'destination': 'ROM',
#            'distance': 8097,
#            'duration': 1196,
#            'found_at': '2018-09-30T18:51:06',
#            'gate': 'Justairticket',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-05-05',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 574.0},
#           {'actual': True,
#            'depart_date': '2018-12-01',
#            'destination': 'MUC',
#            'distance': 7697,
#            'duration': 1026,
#            'found_at': '2018-09-30T20:57:27',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-12-09',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 574.35},
#           {'actual': True,
#            'depart_date': '2018-12-21',
#            'destination': 'PSC',
#            'distance': 3238,
#            'duration': 412,
#            'found_at': '2018-09-30T18:32:25',
#            'gate': 'MyHolidays',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-12-31',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 576.88},
#           {'actual': True,
#            'depart_date': '2018-10-08',
#            'destination': 'GJT',
#            'distance': 2236,
#            'duration': 329,
#            'found_at': '2018-10-01T14:38:53',
#            'gate': 'CompassFlights',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-10-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 610.26},
#           {'actual': True,
#            'depart_date': '2018-12-28',
#            'destination': 'DUB',
#            'distance': 6320,
#            'duration': 1889,
#            'found_at': '2018-09-30T04:54:34',
#            'gate': 'FareDepot',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-31',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 621.29},
#           {'actual': True,
#            'depart_date': '2019-02-19',
#            'destination': 'PRG',
#            'distance': 7776,
#            'duration': 1875,
#            'found_at': '2018-09-30T06:53:54',
#            'gate': 'Cheapfaremart',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-02-26',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 626.87},
#           {'actual': True,
#            'depart_date': '2018-10-24',
#            'destination': 'TPE',
# ...
#            'gate': 'Travelgenio',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-03-25',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 950.84},
#           {'actual': True,
#            'depart_date': '2018-10-24',
#            'destination': 'LOS',
#            'distance': 9401,
#            'duration': 1640,
#            'found_at': '2018-09-30T22:13:05',
#            'gate': 'City.Travel',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-10-31',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 953.66},
#           {'actual': True,
#            'depart_date': '2018-12-02',
#            'destination': 'DEL',
#            'distance': 12832,
#            'duration': 2415,
#            'found_at': '2018-10-01T00:00:51',
#            'gate': 'SmartFares',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-12-24',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 957.96},
#           {'actual': True,
#            'depart_date': '2018-12-16',
#            'destination': 'MOW',
#            'distance': 8661,
#            'duration': 2125,
#            'found_at': '2018-09-30T04:35:32',
#            'gate': 'OZON.travel',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-01-07',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 977.37},
#           {'actual': True,
#            'depart_date': '2018-12-20',
#            'destination': 'NAP',
#            'distance': 8283,
#            'duration': 1889,
#            'found_at': '2018-09-30T01:10:40',
#            'gate': 'CheapTickets24.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 987.14},
#           {'actual': True,
#            'depart_date': '2019-04-03',
#            'destination': 'RAK',
#            'distance': 6984,
#            'duration': 2838,
#            'found_at': '2018-09-30T11:44:56',
#            'gate': 'Cheaptickets.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-04-10',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 990.1},
#           {'actual': True,
#            'depart_date': '2018-11-09',
#            'destination': 'ADD',
#            'distance': 12386,
#            'duration': 1835,
#            'found_at': '2018-09-29T20:49:48',
#            'gate': 'JustFly',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-11-18',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 993.53},
#           {'actual': True,
#            'depart_date': '2019-03-01',
#            'destination': 'COK',
#            'distance': 14744,
#            'duration': 2880,
#            'found_at': '2018-10-01T15:55:39',
#            'gate': 'Justairticket',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-03-17',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 996.0},
#           {'actual': True,
#            'depart_date': '2018-12-23',
#            'destination': 'GND',
#            'distance': 3335,
#            'duration': 1370,
#            'found_at': '2018-09-30T17:57:36',
#            'gate': 'MyHolidays',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-02',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 997.12},
#           {'actual': True,
#            'depart_date': '2019-05-12',
#            'destination': 'KRK',
#            'distance': 8107,
#            'duration': 1073,
#            'found_at': '2018-09-30T16:09:38',
#            'gate': 'Justairticket',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-05-26',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1023.0},
#           {'actual': True,
#            'depart_date': '2018-10-16',
#            'destination': 'NAG',
#            'distance': 13685,
#            'duration': 1855,
#            'found_at': '2018-09-30T03:51:11',
#            'gate': 'Justairticket',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-10-31',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1042.98},
#           {'actual': True,
#            'depart_date': '2018-12-30',
#            'destination': 'KOA',
#            'distance': 7156,
#            'duration': 2240,
#            'found_at': '2018-10-01T04:56:12',
#            'gate': 'JustFly',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-03',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1045.0},
#           {'actual': True,
#            'depart_date': '2019-02-25',
#            'destination': 'DAD',
#            'distance': 14335,
#            'duration': 2088,
#            'found_at': '2018-09-30T16:30:01',
#            'gate': 'FareDepot',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-03-11',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1049.46},
#           {'actual': True,
#            'depart_date': '2019-01-09',
#            'destination': 'IZM',
#            'distance': 9351,
#            'duration': 1900,
#            'found_at': '2018-10-01T15:47:32',
#            'gate': 'Vayama',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-02-01',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1057.0},
#           {'actual': True,
#            'depart_date': '2019-04-01',
#            'destination': 'JNB',
#            'distance': 13582,
#            'duration': 2111,
#            'found_at': '2018-09-29T22:12:12',
#            'gate': 'Mytrip.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-04-05',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1072.78},
#           {'actual': True,
#            'depart_date': '2018-10-20',
#            'destination': 'SEL',
#            'distance': 11460,
#            'duration': 1787,
#            'found_at': '2018-09-29T22:01:45',
#            'gate': 'Travelgenio',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-11-09',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1080.4},
#           {'actual': True,
#            'depart_date': '2018-12-09',
#            'destination': 'BKK',
#            'distance': 14728,
#            'duration': 2725,
#            'found_at': '2018-09-30T16:04:20',
#            'gate': 'FareDepot',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-12-22',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1092.84},
#           {'actual': True,
#            'depart_date': '2019-06-12',
#            'destination': 'ITO',
#            'distance': 7065,
#            'duration': 922,
#            'found_at': '2018-10-01T03:31:26',
#            'gate': 'Vayama',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-06-19',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1128.84},
#           {'actual': True,
#            'depart_date': '2018-11-30',
#            'destination': 'HYD',
#            'distance': 14062,
#            'duration': 2885,
#            'found_at': '2018-10-01T15:00:48',
#            'gate': 'OneTravel',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-12-24',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1158.08},
#           {'actual': True,
#            'depart_date': '2019-03-29',
#            'destination': 'KTM',
#            'distance': 13112,
#            'duration': 1775,
#            'found_at': '2018-10-01T13:56:50',
#            'gate': 'FareDepot',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2019-04-06',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1192.12},
#           {'actual': True,
#            'depart_date': '2018-11-28',
#            'destination': 'AMD',
#            'distance': 13260,
#            'duration': 3830,
#            'found_at': '2018-09-30T23:47:26',
#            'gate': 'FlightNetwork',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-03',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1201.21},
#           {'actual': True,
#            'depart_date': '2018-12-28',
#            'destination': 'PMW',
#            'distance': 6195,
#            'duration': 1380,
#            'found_at': '2018-09-30T21:33:09',
#            'gate': 'MyHolidays',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-28',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1209.99},
#           {'actual': True,
#            'depart_date': '2019-06-12',
#            'destination': 'JHM',
#            'distance': 7149,
#            'duration': 1013,
#            'found_at': '2018-10-01T03:35:02',
#            'gate': 'MyHolidays',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-06-19',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1224.69},
#           {'actual': True,
#            'depart_date': '2019-03-09',
#            'destination': 'AKL',
#            'distance': 13056,
#            'duration': 1660,
#            'found_at': '2018-09-30T16:24:46',
#            'gate': 'FareDepot',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-03-16',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1238.62},
#           {'actual': True,
#            'depart_date': '2018-12-07',
#            'destination': 'MAA',
#            'distance': 14584,
#            'duration': 3055,
#            'found_at': '2018-09-30T21:25:48',
#            'gate': 'MyHolidays',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-12-15',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1260.3},
#           {'actual': True,
#            'depart_date': '2018-11-01',
#            'destination': 'LFW',
#            'distance': 9235,
#            'duration': 2100,
#            'found_at': '2018-10-01T15:37:18',
#            'gate': 'JustFly',
#            'number_of_changes': 1,
#            'origin': 'ATL',
#            'return_date': '2018-11-30',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1345.57},
#           {'actual': True,
#            'depart_date': '2018-12-14',
#            'destination': 'BJS',
#            'distance': 11564,
#            'duration': 1895,
#            'found_at': '2018-10-01T03:49:36',
#            'gate': 'FareDepot',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-12',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1407.2},
#           {'actual': True,
#            'depart_date': '2019-06-25',
#            'destination': 'KUL',
#            'distance': 15882,
#            'duration': 2805,
#            'found_at': '2018-09-30T16:39:12',
#            'gate': 'Justairticket',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-07-24',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1409.0},
#           {'actual': True,
#            'depart_date': '2019-06-25',
#            'destination': 'DPS',
#            'distance': 16608,
#            'duration': 1968,
#            'found_at': '2018-09-30T16:34:34',
#            'gate': 'Vayama',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-07-24',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1450.99},
#           {'actual': True,
#            'depart_date': '2019-03-22',
#            'destination': 'JTR',
#            'distance': 9366,
#            'duration': 1725,
#            'found_at': '2018-10-01T05:50:33',
#            'gate': 'SmartFares',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-03-26',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1481.36},
#           {'actual': True,
#            'depart_date': '2018-12-03',
#            'destination': 'MGQ',
#            'distance': 13442,
#            'duration': 2490,
#            'found_at': '2018-09-30T00:43:57',
#            'gate': 'Vayama',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-12-13',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1494.99},
#           {'actual': True,
#            'depart_date': '2018-11-17',
#            'destination': 'OUA',
#            'distance': 8606,
#            'duration': 3006,
#            'found_at': '2018-09-30T20:24:30',
#            'gate': 'JustFly',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-05',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1612.49},
#           {'actual': True,
#            'depart_date': '2018-12-17',
#            'destination': 'SHA',
#            'distance': 12311,
#            'duration': 2199,
#            'found_at': '2018-10-01T16:45:37',
#            'gate': 'MyHolidays',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-05',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1760.05},
#           {'actual': True,
#            'depart_date': '2018-12-20',
#            'destination': 'HER',
#            'distance': 9417,
#            'duration': 1460,
#            'found_at': '2018-10-01T00:57:07',
#            'gate': 'SmartFares',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-03',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 1824.27},
#           {'actual': True,
#            'depart_date': '2018-12-08',
#            'destination': 'BOB',
#            'distance': 9061,
#            'duration': 1851,
#            'found_at': '2018-09-29T21:54:48',
#            'gate': 'Mytrip.com',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-12-16',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 2203.96},
#           {'actual': True,
#            'depart_date': '2018-12-23',
#            'destination': 'PDP',
#            'distance': 8222,
#            'duration': 2420,
#            'found_at': '2018-10-01T18:35:28',
#            'gate': 'MyHolidays',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2019-01-04',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 2593.01},
#           {'actual': True,
#            'depart_date': '2018-11-24',
#            'destination': 'JMK',
#            'distance': 9289,
#            'duration': 1530,
#            'found_at': '2018-09-29T20:52:20',
#            'gate': 'JustFly',
#            'number_of_changes': 2,
#            'origin': 'ATL',
#            'return_date': '2018-11-25',
#            'show_to_affiliates': True,
#            'trip_class': 0,
#            'value': 7059.01}],
#  'success': True}

# %%
# Gather purchased ticket data (eceonomy class) from the last 48 hours
hubs=["ATL","NYC","HKG","CDG","GIG","JNB"]
# leaving [Atlanta, New York City, Hong Kong, Paris, Rio de Janiero, Johannesburg]

# Desired data
prices=[]
origins=[]
destinations=[]
distances=[]
departs=[]
returns=[]
purchases=[]
cheapests=[]
transfers=[]


# Request up to 500 flights from each hub 
for hub in hubs:
    prices_url=f"http://api.travelpayouts.com/v2/prices/latest?currency=usd&limit=500&origin={hub}"
    headers = {"X-Access-Token": "f2b1a8fac25474496ea091529cddd0ec",
             }
    prices_data = requests.get(prices_url, headers=headers).json()

    for i in prices_data["data"]:
        destination=i["destination"]
        depart=i["depart_date"]
        returnon=i["return_date"]
#       Pull data for cheapest flight of the same parameters
        month_data = requests.get(f"http://api.travelpayouts.com/v1/prices/calendar?currency=usd&origin={hub}&destination={destination}&depart_date={depart}&return_at={returnon}", headers=headers).json()
        if len(month_data["data"])>0:
            day_data=month_data["data"][returnon]
            cheapest=day_data["price"]
            transfer=day_data["transfers"]
            cheapests.append(cheapest)
            transfers.append(transfer)
            prices.append(i["value"])
            origins.append(hub)
            destinations.append(destination)
            distances.append(int(int(i["distance"])//1.609)) #convert km to miles
            departs.append(depart)
            purchases.append(i["found_at"])
            returns.append(returnon)

# Store data into dataframe 
prices_df=pd.DataFrame({"Origin":origins,
                        "Destination":destinations,
                        "Distance (Miles)":distances,
                        "Departure Date":departs,
                        "Return Date":returns,
                        "Price (USD)":prices,
                        "Cheapest Price":cheapests,
                        "Layovers":transfers,
                        "Purchase Time":purchases
                       })
prices_df
# Out:
#     Origin Destination  Distance (Miles) Departure Date Return Date  \
# 0      ATL         CHI               589     2018-12-01  2018-12-08
# 1      ATL         HOU               702     2018-10-26  2018-10-29
# 2      ATL         BOS               937     2018-11-09  2018-11-11
# 3      ATL         PHL               666     2018-10-26  2018-10-29
# 4      ATL         TPA               417     2018-10-14  2018-10-16
# 5      ATL         MSY               424     2018-10-18  2018-10-20
# 6      ATL         NYC               747     2018-10-31  2018-11-03
# 7      ATL         DEN              1211     2018-10-12  2018-10-15
# 8      ATL         DAB               371     2019-02-01  2019-02-04
# 9      ATL         CHO               449     2018-11-03  2018-11-07
# 10     ATL         CLE               556     2018-12-20  2018-12-27
# 11     ATL         SAT               882     2018-10-27  2018-10-29
# 12     ATL         WAS               542     2019-02-14  2019-02-17
# 13     ATL         PBI               551     2018-11-10  2018-11-12
# 14     ATL         MKC               674     2018-11-28  2019-01-03
# 15     ATL         IND               426     2018-12-18  2018-12-21
# 16     ATL         LAX              1935     2018-11-12  2018-12-10
# 17     ATL         SLC              1587     2018-10-29  2018-11-01
# 18     ATL         PHX              1591     2018-10-31  2018-11-03
# 19     ATL         RDU               349     2018-11-18  2018-11-20
# 20     ATL         SYR               782     2018-12-14  2019-01-12
# 21     ATL         CVG               369     2018-10-19  2018-10-21
# 22     ATL         SJU              1546     2019-01-25  2019-01-28
# 23     ATL         PIT               522     2018-12-20  2018-12-29
# 24     ATL         CLT               226     2018-10-17  2018-10-17
# 25     ATL         VPS               257     2018-12-30  2019-01-03
# 26     ATL         SAC              2084     2018-10-13  2018-10-16
# 27     ATL         BIS              1243     2018-10-31  2018-11-05
# 28     ATL         MKE               669     2018-12-19  2018-12-27
# 29     ATL         SEA              2181     2018-11-30  2018-12-04
# ..     ...         ...               ...            ...         ...
# 778    JNB         ROM              4815     2018-12-10  2018-12-17
# 779    JNB         POL              1221     2018-12-27  2019-01-04
# 780    JNB         TLV              4052     2018-10-31  2018-11-06
# 781    JNB         BKK              5596     2018-10-13  2018-10-26
# 782    JNB         TNR              1341     2018-12-06  2018-12-10
# 783    JNB         HKT              5275     2018-10-16  2018-10-23
# 784    JNB         HYD              4537     2018-11-02  2018-11-18
# 785    JNB         PAR              5430     2019-04-11  2019-04-20
# 786    JNB         ABJ              3055     2018-10-14  2018-10-17
# 787    JNB         IBZ              4822     2018-11-21  2018-11-28
# 788    JNB         PNR              1825     2018-12-15  2019-01-25
# 789    JNB         BCN              4962     2018-12-24  2019-01-05
# 790    JNB         DUB              5881     2018-12-26  2019-01-06
# 791    JNB         TLL              5928     2019-02-07  2019-03-11
# 792    JNB         HEL              5978     2019-02-07  2019-03-11
# 793    JNB         BHX              5737     2018-11-16  2018-11-23
# 794    JNB         MOW              5698     2019-08-01  2019-08-15
# 795    JNB         FRA              5409     2018-10-04  2018-10-12
# 796    JNB         DEL              4996     2018-12-23  2019-01-04
# 797    JNB         MAN              5804     2019-04-15  2019-08-25
# 798    JNB         LHE              5016     2018-10-14  2019-02-13
# 799    JNB         MLA              4383     2018-12-02  2019-01-09
# 800    JNB         CHI              8699     2018-12-05  2019-01-30
# 801    JNB         WAS              8116     2019-03-05  2019-03-18
# 802    JNB         SGN              5865     2018-12-22  2019-01-03
# 803    JNB         YMQ              8039     2019-02-04  2019-02-20
# 804    JNB         RRG              2285     2018-12-12  2018-12-18
# 805    JNB         AMM              4031     2018-12-25  2019-01-07
# 806    JNB         YOW              8139     2019-02-27  2019-03-23
# 807    JNB         AKL              7582     2019-04-24  2019-07-08
#
#      Price (USD)  Cheapest Price  Layovers        Purchase Time
# 0          96.81             241         3  2018-09-30T17:45:58
# 1         108.37             225         3  2018-09-29T21:50:00
# 2         111.53             148         2  2018-09-30T23:08:13
# 3         117.78             233         3  2018-10-01T17:54:26
# 4         118.78             308         3  2018-09-30T22:09:53
# 5         125.60             216         3  2018-10-01T00:24:51
# 6         127.91             249         3  2018-10-01T07:41:08
# 7         152.95             293         3  2018-09-30T23:46:34
# 8         152.99             546         3  2018-09-30T21:25:24
# 9         168.67             198         0  2018-09-30T01:18:11
# 10        169.92             372         3  2018-10-01T11:27:08
# 11        181.31             246         2  2018-09-30T01:59:31
# 12        186.83             311         2  2018-09-30T21:48:53
# 13        188.81             390         3  2018-09-29T20:10:18
# 14        189.01             321         4  2018-09-30T23:44:25
# 15        190.80             196         2  2018-09-30T20:56:29
# 16        199.02             234         2  2018-09-29T23:06:16
# 17        202.00             437         0  2018-09-30T00:13:28
# 18        202.88             311         3  2018-09-30T16:04:35
# 19        209.82             307         2  2018-10-01T06:33:20
# 20        219.99             228         2  2018-10-01T03:05:41
# 21        219.99             258         2  2018-10-01T17:45:46
# 22        220.41             430         0  2018-09-30T01:40:51
# 23        225.81             226         2  2018-10-01T03:09:37
# 24        235.29             501         0  2018-09-30T04:55:19
# 25        237.93             423         2  2018-10-01T04:52:09
# 26        240.90             693         0  2018-10-01T16:54:53
# 27        253.59             247         2  2018-09-30T11:50:45
# 28        261.00             867         3  2018-09-30T14:51:40
# 29        264.20             358         0  2018-10-01T06:48:20
# ..           ...             ...       ...                  ...
# 778       464.49            1032         3  2018-09-29T21:38:34
# 779       464.88             511         2  2018-10-01T18:25:03
# 780       499.37             766         3  2018-09-30T12:46:18
# 781       513.35             946         3  2018-10-01T12:47:44
# 782       533.74            1563         3  2018-10-01T13:42:31
# 783       543.49             730         3  2018-10-01T18:19:43
# 784       560.48             717         1  2018-09-30T04:15:24
# 785       578.62            1832         3  2018-10-01T13:42:38
# 786       590.98             719         3  2018-10-01T10:23:26
# 787       597.19            1061         3  2018-09-30T21:08:45
# 788       613.58            4249         3  2018-09-30T06:23:40
# 789       616.90            1178         4  2018-09-30T20:32:14
# 790       619.17            1101         3  2018-10-01T14:03:12
# 791       621.17             657         2  2018-10-01T09:29:55
# 792       624.25             638         2  2018-10-01T09:28:52
# 793       626.23            1088         3  2018-10-01T16:45:11
# 794       645.37            1348         3  2018-09-30T18:16:02
# 795       656.39            1040         0  2018-10-01T17:58:23
# 796       672.17             933         3  2018-09-30T17:50:43
# 797       681.64             691         2  2018-10-01T07:32:14
# 798       715.77            1165         3  2018-09-30T07:53:44
# 799       721.46            1112         3  2018-10-01T08:49:39
# 800       750.99            1295         3  2018-10-01T18:21:30
# 801       750.99            1028         0  2018-10-01T12:53:01
# 802       763.20            1319         3  2018-09-30T20:43:18
# 803       841.58             862         3  2018-10-01T18:35:17
# 804       843.00            3659         2  2018-10-01T19:22:19
# 805       852.27            1155         3  2018-10-01T06:51:14
# 806       884.55            1050         1  2018-09-30T03:37:50
# 807       919.99            1238         3  2018-10-01T07:08:16
#
# [808 rows x 9 columns]

# %%
headers = {"X-Access-Token": "f2b1a8fac25474496ea091529cddd0ec"}
cheapest_data = requests.get("http://api.travelpayouts.com/v1/prices/cheap?currency=usd&origin=ATL&destination=ORL", headers=headers).json()
pprint(cheapest_data)
# Out:
# {'currency': 'usd',
#  'data': {'ORL': {'0': {'airline': 'F9',
#                         'departure_at': '2018-10-09T21:43:00Z',
#                         'expires_at': '2018-10-04T01:47:53Z',
#                         'flight_number': 1560,
#                         'price': 56,
#                         'return_at': '2018-10-10T22:25:00Z'},
#                   '1': {'airline': 'F9',
#                         'departure_at': '2018-12-01T20:49:00Z',
#                         'expires_at': '2018-10-03T02:29:55Z',
#                         'flight_number': 1560,
#                         'price': 85,
#                         'return_at': '2018-12-08T19:58:00Z'},
#                   '2': {'airline': 'F9',
#                         'departure_at': '2018-12-01T20:49:00Z',
#                         'expires_at': '2018-10-03T02:29:55Z',
#                         'flight_number': 1560,
#                         'price': 141,
#                         'return_at': '2018-12-08T06:33:00Z'},
#                   '3': {'airline': 'NK',
#                         'departure_at': '2018-10-26T06:00:00Z',
#                         'expires_at': '2018-10-04T12:50:34Z',
#                         'flight_number': 675,
#                         'price': 213,
#                         'return_at': '2018-11-07T14:09:00Z'},
#                   '4': {'airline': 'F9',
#                         'departure_at': '2018-10-25T21:29:00Z',
#                         'expires_at': '2018-10-04T04:08:34Z',
#                         'flight_number': 423,
#                         'price': 726,
#                         'return_at': '2018-10-28T06:00:00Z'}}},
#  'error': None,
#  'success': True}

# %%
headers = {"X-Access-Token": "f2b1a8fac25474496ea091529cddd0ec"}
month_data = requests.get("http://api.travelpayouts.com/v1/prices/calendar?currency=usd&origin=ATL&destination=ORL&depart_date=2018-11-03&return_at=2018-11-09", headers=headers).json()
pprint(month_data)
# Out:
# {'currency': 'usd',
#  'data': {'2018-11-09': {'airline': 'F9',
#                          'departure_at': '2018-11-03T15:14:00Z',
#                          'destination': 'ORL',
#                          'expires_at': '2018-10-02T20:52:47Z',
#                          'flight_number': 1905,
#                          'origin': 'ATL',
#                          'price': 573,
#                          'return_at': '2018-11-09T15:27:00Z',
#                          'transfers': 3}},
#  'error': None,
#  'success': True}

# %%
time="2018-10-04T04:08:34Z"
date=time.split("T")
date[0]
# Out:
# '2018-10-04'

# %%
headers = {"X-Access-Token": "f2b1a8fac25474496ea091529cddd0ec"}
cheapmonth_data = requests.get("http://api.travelpayouts.com/v1/prices/monthly?currency=usd&origin=ATL&destination=ORL", headers=headers).json()
pprint(cheapmonth_data)
# Out:
# {'currency': 'usd',
#  'data': {'2018-10': {'airline': 'F9',
#                       'departure_at': '2018-10-09T21:43:00Z',
#                       'destination': 'ORL',
#                       'expires_at': '2018-10-04T01:47:53Z',
#                       'flight_number': 1560,
#                       'origin': 'ATL',
#                       'price': 56,
#                       'return_at': '2018-10-10T22:25:00Z',
#                       'transfers': 0},
#           '2018-12': {'airline': 'F9',
#                       'departure_at': '2018-12-01T20:49:00Z',
#                       'destination': 'ORL',
#                       'expires_at': '2018-10-03T02:29:55Z',
#                       'flight_number': 1560,
#                       'origin': 'ATL',
#                       'price': 66,
#                       'return_at': '2018-12-08T08:20:00Z',
#                       'transfers': 0}},
#  'error': None,
#  'success': True}
